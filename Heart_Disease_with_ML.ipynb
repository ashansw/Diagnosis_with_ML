# %% [markdown]
# <a href="https://colab.research.google.com/github/ashansw/Diagnosis_with_ML/blob/main/Heart_Disease_with_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description : This Program classifies a person as having a cardiovascular disease (1) or not (0)

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0eb78a7e-a39e-4606-9d55-1b11bc2c1e19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0eb78a7e-a39e-4606-9d55-1b11bc2c1e19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
# Store the data in a variable
df = pd.read_csv('heart.csv')

# Print the first 10 rows of data
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
# 5   58    0   0       100   248    0  ...      0      1.0      1   0     2       1
# 6   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 7   55    1   0       160   289    0  ...      1      0.8      1   1     3       0
# 8   46    1   0       120   249    0  ...      0      0.8      2   0     3       0
# 9   54    1   0       122   286    0  ...      1      3.2      1   2     2       0
#
# [10 rows x 14 columns]

# %%
# Get the shape of data
df.shape
# Out:
# (1025, 14)

# %%
# Calculate empty/null values of the dataset
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Another way to detect missing values
df.isnull().values.any()
# Out:
# False

# %%
# View some basic statistics related to the dataset. Example: Mean, Standard deviation etc.
df.describe()
# Out:
#                age          sex  ...         thal       target
# count  1025.000000  1025.000000  ...  1025.000000  1025.000000
# mean     54.434146     0.695610  ...     2.323902     0.513171
# std       9.072290     0.460373  ...     0.620660     0.500070
# min      29.000000     0.000000  ...     0.000000     0.000000
# 25%      48.000000     0.000000  ...     2.000000     0.000000
# 50%      56.000000     1.000000  ...     2.000000     1.000000
# 75%      61.000000     1.000000  ...     3.000000     1.000000
# max      77.000000     1.000000  ...     3.000000     1.000000
#
# [8 rows x 14 columns]

# %%
# Getting a count of number of individuals with heart disease and without heart disease
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
# Visualize individuals with heart disease and without heart disease
sns.countplot(df['target'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Visualize the the number of people with heart disease and without heart disease with respect to age
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.countplot(x='age', hue='target', data=df, palette="bright")

# Another way to resize the plot according to the required dimensions
# sns.countplot(x='age', hue='target', data=df, palette="bright")
# sns.set(rc={'figure.figsize':(15,10)})

# %%
# Correlation between columns (features) - How columns are correlated with each other
df.corr()
# Out:
#                age       sex        cp  ...        ca      thal    target
# age       1.000000 -0.103240 -0.071966  ...  0.271551  0.072297 -0.229324
# sex      -0.103240  1.000000 -0.041119  ...  0.111729  0.198424 -0.279501
# cp       -0.071966 -0.041119  1.000000  ... -0.176206 -0.163341  0.434854
# trestbps  0.271121 -0.078974  0.038177  ...  0.104554  0.059276 -0.138772
# chol      0.219823 -0.198258 -0.081641  ...  0.074259  0.100244 -0.099966
# fbs       0.121243  0.027200  0.079294  ...  0.137156 -0.042177 -0.041164
# restecg  -0.132696 -0.055117  0.043581  ... -0.078072 -0.020504  0.134468
# thalach  -0.390227 -0.049365  0.306839  ... -0.207888 -0.098068  0.422895
# exang     0.088163  0.139157 -0.401513  ...  0.107849  0.197201 -0.438029
# oldpeak   0.208137  0.084687 -0.174733  ...  0.221816  0.202672 -0.438441
# slope    -0.169105 -0.026666  0.131633  ... -0.073440 -0.094090  0.345512
# ca        0.271551  0.111729 -0.176206  ...  1.000000  0.149014 -0.382085
# ...

# %%
# Visualize the correlation using a heathmap
sns.heatmap(df.corr())

# %%
# Visualize the correlation using a heathmap with increased figure size and with annotations
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)

# %%
# Visualize the data using a heathmap with increased figure size and annotations with percentages
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True, fmt='.0%')

# %%
#Split the data into feature data and target data
X = df
